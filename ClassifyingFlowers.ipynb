# %%
import pandas as pd
from sklearn.datasets import load_iris #usually will read the dataset from a csv

# %%
import matplotlib.pyplot as plt

# %%
# numpy for numerical operations, matplotlib for plotting, and scikit-learn for regression modeling
import numpy as np
# Importing LinearRegression from scikit-learn to create the linear regression model
from sklearn.linear_model import LinearRegression
# train_test_split to split the dataset into training and testing subsets
from sklearn.model_selection import train_test_split
# mean_squared_error to measure the error and r2_score to evaluate the model's performance
from sklearn.metrics import mean_squared_error, r2_score

# %%
# iris = pd.read_csv("/Iris.csv")

# %%
from sklearn.model_selection import train_test_split

# %%
data = load_iris()
df = pd.DataFrame(data.data, columns=data.feature_names) #splitting the iris dataset into its column names, converting into a dataframe for easier manipulation
df["target"] = data.target #gives us a target column
df.isna().sum() #checks for rows with an NA value, and sums them up- checks for null values in data set
df.dropna(inplace=True) #naive way to remove null values
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
# ..      ...
# 145       2
# 146       2
# 147       2
# 148       2
# 149       2
#
# [150 rows x 5 columns]

# %%
data.target_names
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %%
X = df.drop(columns=["target"])
X #exact same with no target columns
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %%
Y = df["target"]
Y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 145    2
# 146    2
# 147    2
# 148    2
# 149    2
# Name: target, Length: 150, dtype: int64

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=0) #splits the testing size into 20%

# %%
x_train.shape #shape tells you how many rows and how many columns
# Out:
# (120, 4)

# %%
x_test.shape
# Out:
# (30, 4)

# %%
y_train.shape
# Out:
# (120,)

# %%
y_test.shape
# Out:
# (30,)

# %%
# Create and train the model
# Importing LinearRegression from scikit-learn to create the linear regression model
model = LinearRegression()
model.fit(x_train, y_train) # the function to fit the model to the training data
# Out:
# LinearRegression()

# %%
# Make predictions
y_pred = model.predict(x_test)
y_pred[:5]  # Display first 5 predictions
# Out:
# array([ 2.06844113,  0.96345869, -0.14707913,  1.81304847, -0.03927091])

# %%
# Evaluate the model
# mean_squared_error to measure the error and r2_score to evaluate the model's performance
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
print(f'Mean squared error: {mse:.2f}')
print(f'R^2 score: {r2:.2f}')
# Out:
# Mean squared error: 0.05
# R^2 score: 0.91

# %%
plt.figure(figsize = (8,6))

# %%
#scatter plot for logistical regression data for x and y
plt.scatter(y_test, y_pred, alpha = 0.5)
plt.title('True vs Predicted Value')
plt.xlabel('True Values')
plt.ylabel('Predicted Values')
plt.show()

# %%
#GIT PUSHING
# !git config --global user.email "gjf5257@psu.edu"
# !git config --global user.name "GFPrasanna"

# %%
# !git clone https://github.com/GFPrasanna/MachineLearningBootcamp
# Out:
# Cloning into 'MachineLearningBootcamp'...
# warning: You appear to have cloned an empty repository.
